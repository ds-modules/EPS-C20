# %% [markdown]
# # Tables and Maps

# %%
# first import required libraries and settings
import numpy as np
from datascience import *
# %matplotlib inline
import obspy

# %% [markdown]
# First, let's read in some data from the [USGS Earthquake Records](https://earthquake.usgs.gov/data/).
# The file in this directory is a spreadsheet of information about all the earthquakes recorded in the month of September 2017.

# %%
quakes = Table.read_table("last_month_earthquakes.csv")
coords = quakes.select('latitude', 'longitude', 'place')
#plotting the first 100 elements
Marker.map_table(coords.take(np.arange(0, 100)))
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_200da68d1e4049018e52b5c3e99319f5&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: -1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_200da68d1e4049018e52b5c3e99319f5', {
#                                        center:[17.02695, 3.28915],
#                                        zoom: 1,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([59.3154,
# 							-153.6635],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;85km SE of Old Iliamna, Alaska&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([37.5723343,
# 							-118.8426666],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;14km SE of Mammoth Lakes, California&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([33.3261667,
# 							-116.7558333],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;9km N of Lake Henshaw, CA&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([33.3253333,
# 							-116.7738333],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;9km ESE of Palomar Observatory, CA&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([36.5836678,
# 							-121.1685028],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;22km NE of Soledad, California&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([33.9506667,
# 							-116.9188333],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;5km NW of Banning, CA&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([59.7625,
# 							-136.6921],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;84km WNW of Skagway, Alaska&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([34.6876667,
# 							-120.2631667],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;6km SSE of Los Alamos, CA&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([59.7803,
# 							-136.6848],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;85km WNW of Skagway, Alaska&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([33.9951667,
# 							-118.675],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;4km SSE of Malibu Beach, CA&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([38.6247,
# 							-118.2932],
# 							{'icon':marker_11_icon}
# 							);
#       marker_11.bindPop

# %% [markdown]
# The map above shows the first 100 earthquakes in our dataset. Run the cell below to input the number of earthquakes you want displayed.

# %%
num_quakes = int(input("How many earthquakes do you want to see? "))
Marker.map_table(coords.take(np.arange(num_quakes + 1)))
# Out:
# How many earthquakes do you want to see? 250
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_ce2da123e46a4dedb4c5d12af1d4714c&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: -1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_ce2da123e46a4dedb4c5d12af1d4714c', {
#                                        center:[17.1837, -7.0924],
#                                        zoom: 1,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([59.3154,
# 							-153.6635],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;85km SE of Old Iliamna, Alaska&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([37.5723343,
# 							-118.8426666],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;14km SE of Mammoth Lakes, California&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([33.3261667,
# 							-116.7558333],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;9km N of Lake Henshaw, CA&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([33.3253333,
# 							-116.7738333],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;9km ESE of Palomar Observatory, CA&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([36.5836678,
# 							-121.1685028],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;22km NE of Soledad, California&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([33.9506667,
# 							-116.9188333],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;5km NW of Banning, CA&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([59.7625,
# 							-136.6921],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;84km WNW of Skagway, Alaska&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([34.6876667,
# 							-120.2631667],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;6km SSE of Los Alamos, CA&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([59.7803,
# 							-136.6848],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;85km WNW of Skagway, Alaska&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([33.9951667,
# 							-118.675],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;4km SSE of Malibu Beach, CA&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([38.6247,
# 							-118.2932],
# 							{'icon':marker_11_icon}
# 							);
#       marker_11.bindPopu

# %% [markdown]
# ### Tables
#
# Our earthquake data is stored in a tabular format. Tables can represented in spreadsheets, or in our case, as a data structure containing rows and columns with a well-defined structure. We will use the datascience Python library to read in our data.

# %%
quakes.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>time</th> <th>latitude</th> <th>longitude</th> <th>depth</th> <th>mag</th> <th>magType</th> <th>nst</th> <th>gap</th> <th>dmin</th> <th>rms</th> <th>net</th> <th>id</th> <th>updated</th> <th>place</th> <th>type</th> <th>horizontalError</th> <th>depthError</th> <th>magError</th> <th>magNst</th> <th>status</th> <th>locationSource</th> <th>magSource</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2017-09-30T03:10:29.824Z</td> <td>59.3154 </td> <td>-153.663 </td> <td>106.9</td> <td>2.5 </td> <td>ml     </td> <td>nan </td> <td>nan </td> <td>nan    </td> <td>0.46</td> <td>ak  </td> <td>ak16951083</td> <td>2017-09-30T03:16:22.957Z</td> <td>85km SE of Old Iliamna, Alaska      </td> <td>earthquake</td> <td>nan            </td> <td>0.5       </td> <td>nan     </td> <td>nan   </td> <td>automatic</td> <td>ak            </td> <td>ak       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2017-09-30T02:51:27.750Z</td> <td>37.5723 </td> <td>-118.843 </td> <td>0.35 </td> <td>1.13</td> <td>md     </td> <td>9   </td> <td>220 </td> <td>0.02069</td> <td>0.03</td> <td>nc  </td> <td>nc72902026</td> <td>2017-09-30T02:57:02.746Z</td> <td>14km SE of Mammoth Lakes, California</td> <td>earthquake</td> <td>0.98           </td> <td>0.47      </td> <td>0.19    </td> <td>8     </td> <td>automatic</td> <td>nc            </td> <td>nc       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2017-09-30T02:35:55.270Z</td> <td>33.3262 </td> <td>-116.756 </td> <td>13.61</td> <td>0.62</td> <td>ml     </td> <td>24  </td> <td>63  </td> <td>0.08998</td> <td>0.17</td> <td>ci  </td> <td>ci38015256</td> <td>2017-09-30T02:39:29.578Z</td> <td>9km N of Lake Henshaw, CA           </td> <td>earthquake</td> <td>0.33           </td> <td>0.7       </td> <td>0.153   </td> <td>15    </td> <td>automatic</td> <td>ci            </td> <td>ci       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2017-09-30T02:34:06.370Z</td> <td>33.3253 </td> <td>-116.774 </td> <td>12.64</td> <td>0.6 </td> <td>ml     </td> <td>25  </td> <td>61  </td> <td>0.07952</td> <td>0.22</td> <td>ci  </td> <td>ci38015248</td> <td>2017-09-30T02:37:42.940Z</td> <td>9km ESE of Palomar Observatory, CA  </td> <td>earthquake</td> <td>0.46           </td> <td>0.96      </td> <td>0.122   </td> <td>16    </td> <td>automatic</td> <td>ci            </td> <td>ci       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2017-09-30T02:33:57.910Z</td> <td>36.5837 </td> <td>-121.169 </td> <td>4.28 </td> <td>0.77</td> <td>md     </td> <td>7   </td> <td>168 </td> <td>0.01946</td> <td>0.36</td> <td>nc  </td> <td>nc72902021</td> <td>2017-09-30T02:54:02.740Z</td> <td>22km NE of Soledad, California      </td> <td>earthquake</td> <td>2.14           </td> <td>2.26      </td> <td>0.22    </td> <td>4     </td> <td>automatic</td> <td>nc            </td> <td>nc       </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (9862 rows omitted)</p

# %% [markdown]
# In our dataset, notice how we have various numerical fields, such as `mag`, `depth`, `nst`. We can analyze these fields and discover some information. We can access columns by using .column("column name") on a Table object.

# %%
# taking an average
np.mean(quakes.column('mag'))
# Out:
# nan

# %% [markdown]
# Woah! What happened there? The magnitude column contained some non-numerical values. We can work around that by calling np.nanmean on the column.

# %%
np.nanmean(quakes['mag'])
# Out:
# 1.5682757222503803

# %% [markdown]
# We should also note that there are multiple types of magnitudes. So this number does not represent the original Richter and Gutenberg method for measuring local earthquakes. So instead, let's calculate the average local magnitude.

# %%
local = quakes.where('magType', are.contained_in(['ML MI', "ml", 'mi']))
sum(local['magType'] == 'ml') == len(local['magType'])
avg_local_mag = np.nanmean(local.column("mag"))
print("The average local magnitude is: {}".format(avg_local_mag))

# %%
#mww is the code for moment magnitude
# https://earthquake.usgs.gov/data/comcat/data-eventterms.php#magType
moment = quakes.where('magType', are.equal_to("mww"))
moment
avg_moment_mag = np.nanmean(moment.column("mag"))
print("The average moment magnitude is: {}".format(avg_moment_mag))
# Out:
# The average moment magnitude is: 5.514705882352941

# %%
# nst is number of stations that recorded the quake
print("The average number of stations that recorded each quake was: {}".format(np.nanmean(quakes.column('nst'))))
# Out:
# The average number of stations that recorded each quake was: 19.847359454855194

# %% [markdown]
# **Exercise: Use the .select notation to extract the latitude, longitude, and place columns**
#
# Also use .column to access the depth column. Store this in a variable called depth

# %%
# your code here hint: .select('one thing', 'another', 'the last thing') is the syntax
# store the lat, lon, and place columns in a variable called selection
# Out:
# latitude | longitude | place
# 59.3154  | -153.663  | 85km SE of Old Iliamna, Alaska
# 37.5723  | -118.843  | 14km SE of Mammoth Lakes, California
# 33.3262  | -116.756  | 9km N of Lake Henshaw, CA
# 33.3253  | -116.774  | 9km ESE of Palomar Observatory, CA
# 36.5837  | -121.169  | 22km NE of Soledad, California
# 33.9507  | -116.919  | 5km NW of Banning, CA
# 59.7625  | -136.692  | 84km WNW of Skagway, Alaska
# 34.6877  | -120.263  | 6km SSE of Los Alamos, CA
# 59.7803  | -136.685  | 85km WNW of Skagway, Alaska
# 33.9952  | -118.675  | 4km SSE of Malibu Beach, CA
# ... (9857 rows omitted)

# %% [markdown]
# ### Welcome to ObsPy
#
# ObsPy is a framework for working with seismological data.

# %%
from obspy import read
st = read('http://examples.obspy.org/RJOB_061005_072159.ehz.new')
print(st)
# Out:
# 1 Trace(s) in Stream:
# .RJOB..Z | 2005-10-06T07:21:59.850000Z - 2005-10-06T07:24:59.845000Z | 200.0 Hz, 36000 samples

# %%
st[0][1:5]
# Out:
# array([12, -4,  6, 26], dtype=int32)

# %% [markdown]
# `st` is a file that contains readings from a single station.
